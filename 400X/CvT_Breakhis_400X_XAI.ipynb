# %%
from tqdm import tqdm, trange
import torch
import torchvision
from PIL import Image, ImageDraw
from torchvision import models
from torch.nn import functional as F
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms
from torchvision import utils
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import imagesize
from torch.utils import data
import torch.optim as optim
#from skimage import io, color
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns
import os
from pathlib import Path
from torch.utils.data import SubsetRandomSampler,DataLoader,Dataset
import cv2
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
np.random.seed(0)
torch.manual_seed(0)

# %%
img_path = 'fold1_seperated_2_classes/test/100X/Malignant/SOB_M_DC-14-11520-100-002.png'
img = Image.open(img_path)

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=700x460>

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
#data_path = 'BreakHis/fold1_seperated_2_classes/train/40X'
training_dataset_path = 'fold1_seperated_2_classes/train/400X'
testing_dataset_path = 'fold1_seperated_2_classes/test/400X'

# %%
def image_transform():
  transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.7590, 0.5809, 0.7404],std = [0.1195, 0.1602, 0.0887])
    ])
  return transform

# %%
transform =  image_transform()

# %%
X = transform(img).unsqueeze_(0)

# %%
def load_dataset(path,transform_img):
  data = torchvision.datasets.ImageFolder(root=path, transform=transform)
  return data

# %%
training_dataset = load_dataset(training_dataset_path,transform)
training_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1165
#     Root location: fold1_seperated_2_classes/train/400X
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#                Normalize(mean=[0.759, 0.5809, 0.7404], std=[0.1195, 0.1602, 0.0887])
#            )

# %%
testing_dataset = load_dataset(testing_dataset_path,transform)
testing_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 655
#     Root location: fold1_seperated_2_classes/test/400X
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#                Normalize(mean=[0.759, 0.5809, 0.7404], std=[0.1195, 0.1602, 0.0887])
#            )

# %%
train_loader = torch.utils.data.DataLoader(dataset = training_dataset, batch_size = 8,shuffle=True)

# %%
#Splitting Testing Data into 30% Validation and 70% Testing
dataset_size = len(testing_dataset)
dataset_indices = list(range(dataset_size))
np.random.shuffle(dataset_indices)
val_split_index = int(np.floor(0.3 * dataset_size))
train_idx, val_idx = dataset_indices[val_split_index:], dataset_indices[:val_split_index]
test_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx) 
test_loader = torch.utils.data.DataLoader(dataset = testing_dataset,batch_size = 8,sampler=test_sampler,shuffle=False)
val_loader = DataLoader(dataset= testing_dataset, shuffle=False, batch_size=8, sampler=val_sampler)

# %%
from transformers import CvtConfig, CvtModel
from transformers import AutoImageProcessor, CvtForImageClassification
configuration = CvtConfig()
model = CvtForImageClassification(configuration)

# %%
model.to(device)
# Out:
# CvtForImageClassification(
#   (cvt): CvtModel(
#     (encoder): CvtEncoder(
#       (stages): ModuleList(
#         (0): CvtStage(
#           (embedding): CvtEmbeddings(
#             (convolution_embeddings): CvtConvEmbeddings(
#               (projection): Conv2d(3, 64, kernel_size=(7, 7), stride=(4, 4), padding=(2, 2))
#               (normalization): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             (0): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=64, out_features=64, bias=True)
#                   (projection_key): Linear(in_features=64, out_features=64, bias=True)
#                   (projection_value): Linear(in_features=64, out_features=64, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=64, out_features=64, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=64, out_features=256, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=256, out_features=64, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): Identity()
#               (layernorm_before): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (1): CvtStage(
#           (embedding): CvtEmbeddings(
#             (convolution_embeddings): CvtConvEmbeddings(
#               (projection): Conv2d(64, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (normalization): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             (0): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_key): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_value): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=192, out_features=768, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): Identity()
#               (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#             (1): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_key): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_value): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=192, out_features=768, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): Identity()
#               (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (2): CvtStage(
#           (embedding): CvtEmbeddings(
#             (convolution_embeddings): CvtConvEmbeddings(
#               (projection): Conv2d(192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (normalization): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             (0): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (1): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (2): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (3): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (4): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (5): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (6): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (7): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (8): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (9): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   (classifier): Linear(in_features=384, out_features=2, bias=True)
# )

# %%
model(X.to(device))
# Out:
# ImageClassifierOutputWithNoAttention(loss=None, logits=tensor([[0.3721, 0.2159]], device='cuda:0', grad_fn=<AddmmBackward0>), hidden_states=None)

# %%
N_EPOCHS = 150
LR = 0.0001
optimizer = optim.SGD(model.parameters(), lr=LR,momentum=0.9,weight_decay=0.03)
criterion = CrossEntropyLoss()

# %%
def set_device():
  if torch.cuda.is_available():
    dev = 'cuda:0'
  else:
    dev = 'cpu'
  return torch.device(dev)

# %%
def save_checkpoint(model, epoch, optimizer, best_acc, train_losses, train_acc, val_losses, val_acc):
    state = {
        'epoch': epoch + 1,
        'model': model.state_dict(),
        'best accuracy': best_acc,
        'optimizer': optimizer.state_dict(),
        'train_losses': train_losses,
        'train_acc': train_acc,
        'val_losses': val_losses,
        'val_acc': val_acc
    }
    torch.save(state, 'Models/cvt_400X.pth')

# %%
def evaluate_model(model,test_loader,criterion):
    model.eval()
    predicted_correctly = 0
    total = 0
    device = set_device()
    running_loss = 0.0

    with torch.no_grad(): 
          for data in test_loader:
            images,labels = data
            images = images.to(device)
            labels = labels.to(device)
            total += labels.size(0) 

            outputs = model(images)

            _,predicted = torch.max(outputs.logits,1)
            loss = criterion(outputs.logits,labels)
            running_loss+=loss.item()

            predicted_correctly+=(predicted==labels).sum().item()
    epoch_acc = 100.0*predicted_correctly/total
    epoch_loss = running_loss/len(test_loader)
    print('-  Testing dataset. Got %d out of %d images correctly (%0.3f%%). Loss: %0.3f' % (predicted_correctly, total, epoch_acc,epoch_loss))

    return epoch_acc,epoch_loss

# %%
import time

def train_nn(model, train_loader, test_loader, criterion, optimizer, n_epochs):
    device = set_device()
    best_acc = 0
    train_losses = []
    train_acc = []
    val_acc = []
    val_losses = []
    model = model.to(device)
    scaler = torch.cuda.amp.GradScaler()
    max_epoch_time = 0.0  
    
    for epoch in range(n_epochs):
        start_time = time.time()  
        
        print("Epoch number: %d" % (epoch + 1))
        model.train()
        running_loss = 0.0
        running_correct = 0.0
        total = 0
        
        for images,labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            total += labels.size(0)

            optimizer.zero_grad()
            with torch.cuda.amp.autocast():
                outputs = model(images)
                loss = criterion(outputs.logits, labels)
            
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            running_loss += loss.item()
            _, predicted = torch.max(outputs.logits, 1)
            running_correct += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(train_loader)
        epoch_acc = 100.0 * running_correct / total
        train_losses.append(epoch_loss)
        train_acc.append(epoch_acc)

        print("  -Training Dataset, Got %d out of %d images correctly (%0.3f%%). Epoch Loss: %0.3f" % (
        running_correct, total, epoch_acc, epoch_loss))
        
        test_dataset_acc, test_dataset_loss = evaluate_model(model, test_loader, criterion)
        val_acc.append(test_dataset_acc)
        val_losses.append(test_dataset_loss)
        
        if test_dataset_acc > best_acc:
            best_acc = test_dataset_acc
            save_checkpoint(model, epoch, optimizer, best_acc, train_losses, train_acc, val_losses, val_acc)

        end_time = time.time() 
        epoch_time = end_time - start_time
        
        max_epoch_time = max(max_epoch_time, epoch_time)  
        
        print("Time taken for epoch {}: {:.2f} seconds".format(epoch + 1, epoch_time))
        

    print('Finished Training')
    return model, train_losses, train_acc, val_acc, val_losses, max_epoch_time

# Train the model and get the maximum epoch time
model, train_losses, train_acc, val_acc, val_losses, max_epoch_time = train_nn(model, train_loader, val_loader, criterion, optimizer, 50)
# Out:
# C:\Users\Utkarsh Varman\AppData\Local\Temp\ipykernel_20756\1735945754.py:11: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# Epoch number: 1
# C:\Users\Utkarsh Varman\AppData\Local\Temp\ipykernel_20756\1735945754.py:29: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
#   -Training Dataset, Got 882 out of 1165 images correctly (75.708%). Epoch Loss: 0.520
# -  Testing dataset. Got 160 out of 196 images correctly (81.633%). Loss: 0.471
# Time taken for epoch 1: 40.26 seconds
# Epoch number: 2
#   -Training Dataset, Got 902 out of 1165 images correctly (77.425%). Epoch Loss: 0.490
# -  Testing dataset. Got 161 out of 196 images correctly (82.143%). Loss: 0.422
# Time taken for epoch 2: 40.72 seconds
# Epoch number: 3
#   -Training Dataset, Got 895 out of 1165 images correctly (76.824%). Epoch Loss: 0.479
# -  Testing dataset. Got 153 out of 196 images correctly (78.061%). Loss: 0.466
# Time taken for epoch 3: 38.88 seconds
# Epoch number: 4
#   -Training Dataset, Got 913 out of 1165 images correctly (78.369%). Epoch Loss: 0.451
# -  Testing dataset. Got 164 out of 196 images correctly (83.673%). Loss: 0.481
# Time taken for epoch 4: 38.92 seconds
# Epoch number: 5
#   -Training Dataset, Got 914 out of 1165 images correctly (78.455%). Epoch Loss: 0.455
# -  Testing dataset. Got 152 out of 196 images correctly (77.551%). Loss: 0.525
# Time taken for epoch 5: 39.40 seconds
# Epoch number: 6
#   -Training Dataset, Got 928 out of 1165 images correctly (79.657%). Epoch Loss: 0.435
# -  Testing dataset. Got 155 out of 196 images correctly (79.082%). Loss: 0.497
# Time taken for epoch 6: 38.65 seconds
# Epoch number: 7
#   -Training Dataset, Got 914 out of 1165 images correctly (78.455%). Epoch Loss: 0.452
# -  Testing dataset. Got 160 out of 196 images correctly (81.633%). Loss: 0.481
# Time taken for epoch 7: 38.90 seconds
# Epoch number: 8
#   -Training Dataset, Got 933 out of 1165 images correctly (80.086%). Epoch Loss: 0.431
# -  Testing dataset. Got 158 out of 196 images correctly (80.612%). Loss: 0.485
# Time taken for epoch 8: 38.77 seconds
# Epoch number: 9
#   -Training Dataset, Got 943 out of 1165 images correctly (80.944%). Epoch Loss: 0.420
# -  Testing dataset. Got 163 out of 196 images correctly (83.163%). Loss: 0.460
# Time taken for epoch 9: 38.90 seconds
# Epoch number: 10
#   -Training Dataset, Got 941 out of 1165 images correctly (80.773%). Epoch Loss: 0.419
# -  Testing dataset. Got 161 out of 196 images correctly (82.143%). Loss: 0.480
# Time taken for epoch 10: 38.86 seconds
# Epoch number: 11
#   -Training Dataset, Got 948 out of 1165 images correctly (81.373%). Epoch Loss: 0.402
# -  Testing dataset. Got 162 out of 196 images correctly (82.653%). Loss: 0.486
# Time taken for epoch 11: 38.87 seconds
# Epoch number: 12
#   -Training Dataset, Got 937 out of 1165 images correctly (80.429%). Epoch Loss: 0.401
# -  Testing dataset. Got 161 out of 196 images correctly (82.143%). Loss: 0.499
# Time taken for epoch 12: 38.87 seconds
# Epoch number: 13
#   -Training Dataset, Got 953 out of 1165 images correctly (81.803%). Epoch Loss: 0.410
# -  Testing dataset. Got 162 out of 196 images correctly (82.653%). Loss: 0.505
# Time taken for epoch 13: 38.61 seconds
# Epoch number: 14
#   -Training Dataset, Got 932 out of 1165 images correctly (80.000%). Epoch Loss: 0.411
# -  Testing dataset. Got 159 out of 196 images correctly (81.122%). Loss: 0.484
# Time taken for epoch 14: 38.07 seconds
# Epoch number: 15
#   -Training Dataset, Got 963 out of 1165 images correctly (82.661%). Epoch Loss: 0.393
# -  Testing dataset. Got 160 out of 196 images correctly (81.633%). Loss: 0.538
# Time taken for epoch 15: 38.01 seconds
# Epoch number: 16
#   -Training Dataset, Got 944 out of 1165 images correctly (81.030%). Epoch Loss: 0.397
# -  Testing dataset. Got 150 out of 196 images correctly (76.531%). Loss: 0.557
# Time taken for epoch 16: 38.03 seconds
# Epoch number: 17
#   -Training Dataset, Got 968 out of 1165 images correctly (83.090%). Epoch Loss: 0.387
# -  Testing dataset. Got 164 out of 196 images correctly (83.673%). Loss: 0.493
# Time taken for epoch 17: 38.26 seconds
# Epoch number: 18
#   -Training Dataset, Got 965 out of 1165 images correctly (82.833%). Epoch Loss: 0.378
# -  Testing dataset. Got 161 out of 196 images correctly (82.143%). Loss: 0.474
# Time taken for epoch 18: 38.19 seconds
# Epoch number: 19
#   -Training Dataset, Got 966 out of 1165 images correctly (82.918%). Epoch Loss: 0.400
# -  Testing dataset. Got 155 out of 196 images correctly (79.082%). Loss: 0.508
# Time taken for epoch 19: 42.05 seconds
# Epoch number: 20
#   -Training Dataset, Got 968 out of 1165 images correctly (83.090%). Epoch Loss: 0.360
# -  Testing dataset. Got 155 out of 196 images correctly (79.082%). Loss: 0.518
# Time taken for epoch 20: 37.43 seconds
# Epoch number: 21
#   -Training Dataset, Got 993 out of 1165 images correctly (85.236%). Epoch Loss: 0.340
# -  Testing dataset. Got 150 out of 196 images correctly (76.531%). Loss: 0.598
# Time taken for epoch 21: 38.07 seconds
# Epoch number: 22
#   -Training Dataset, Got 978 out of 1165 images correctly (83.948%). Epoch Loss: 0.368
# -  Testing dataset. Got 159 out of 196 images correctly (81.122%). Loss: 0.527
# Time taken for epoch 22: 37.91 seconds
# Epoch number: 23
#   -Training Dataset, Got 976 out of 1165 images correctly (83.777%). Epoch Loss: 0.363
# -  Testing dataset. Got 162 out of 196 images correctly (82.653%). Loss: 0.471
# Time taken for epoch 23: 38.03 seconds
# Epoch number: 24
#   -Training Dataset, Got 971 out of 1165 images correctly (83.348%). Epoch Loss: 0.349
# -  Testing dataset. Got 157 out of 196 images correctly (80.102%). Loss: 0.568
# Time taken for epoch 24: 38.09 seconds
# Epoch number: 25
#   -Training Dataset, Got 994 out of 1165 images correctly (85.322%). Epoch Loss: 0.338
# -  Testing dataset. Got 162 out of 196 images correctly (82.653%). Loss: 0.506
# Time taken for epoch 25: 37.73 seconds
# Epoch number: 26
#   -Training Dataset, Got 1002 out of 1165 images correctly (86.009%). Epoch Loss: 0.343
# -  Testing dataset. Got 157 out of 196 images correctly (80.102%). Loss: 0.536
# Time taken for epoch 26: 38.29 seconds
# Epoch number: 27
#   -Training Dataset, Got 994 out of 1165 images correctly (85.322%). Epoch Loss: 0.332
# -  Testing dataset. Got 157 out of 196 images correctly (80.102%). Loss: 0.511
# Time taken for epoch 27: 38.22 seconds
# Epoch number: 28
#   -Training Dataset, Got 990 out of 1165 images correctly (84.979%). Epoch Loss: 0.336
# -  Testing dataset. Got 166 out of 196 images correctly (84.694%). Loss: 0.481
# Time taken for epoch 28: 37.76 seconds
# Epoch number: 29
#   -Training Dataset, Got 994 out of 1165 images correctly (85.322%). Epoch Loss: 0.331
# -  Testing dataset. Got 153 out of 196 images correctly (78.061%). Loss: 0.517
# Time taken for epoch 29: 37.40 seconds
# Epoch number: 30
#   -Training Dataset, Got 989 out of 1165 images correctly (84.893%). Epoch Loss: 0.336
# -  Testing dataset. Got 158 out of 196 images correctly (80.612%). Loss: 0.506
# Time taken for epoch 30: 38.12 seconds
# Epoch number: 31
#   -Training Dataset, Got 997 out of 1165 images correctly (85.579%). Epoch Loss: 0.316
# -  Testing dataset. Got 159 out of 196 images correctly (81.122%). Loss: 0.573
# Time taken for epoch 31: 37.25 seconds
# Epoch number: 32
#   -Training Dataset, Got 1017 out of 1165 images correctly (87.296%). Epoch Loss: 0.289
# -  Testing dataset. Got 160 out of 196 images correctly (81.633%). Loss: 0.512
# Time taken for epoch 32: 37.77 seconds
# Epoch number: 33
#   -Training Dataset, Got 1039 out of 1165 images correctly (89.185%). Epoch Loss: 0.285
# -  Testing dataset. Got 158 out of 196 images correctly (80.612%). Loss: 0.590
# Time taken for epoch 33: 37.25 seconds
# Epoch number: 34
#   -Training Dataset, Got 987 out of 1165 images correctly (84.721%). Epoch Loss: 0.329
# -  Testing dataset. Got 156 out of 196 images correctly (79.592%). Loss: 0.554
# Time taken for epoch 34: 37.85 seconds
# Epoch number: 35
#   -Training Dataset, Got 1020 out of 1165 images correctly (87.554%). Epoch Loss: 0.277
# -  Testing dataset. Got 154 out of 196 images correctly (78.571%). Loss: 0.634
# Time taken for epoch 35: 37.76 seconds
# Epoch number: 36
#   -Training Dataset, Got 999 out of 1165 images correctly (85.751%). Epoch Loss: 0.296
# -  Testing dataset. Got 151 out of 196 images correctly (77.041%). Loss: 0.680
# Time taken for epoch 36: 37.84 seconds
# Epoch number: 37
#   -Training Dataset, Got 1015 out of 1165 images correctly (87.124%). Epoch Loss: 0.290
# -  Testing dataset. Got 158 out of 196 images correctly (80.612%). Loss: 0.546
# Time taken for epoch 37: 39.17 seconds
# Epoch number: 38
#   -Training Dataset, Got 1004 out of 1165 images correctly (86.180%). Epoch Loss: 0.306
# -  Testing dataset. Got 159 out of 196 images correctly (81.122%). Loss: 0.512
# Time taken for epoch 38: 38.33 seconds
# Epoch number: 39
#   -Training Dataset, Got 1014 out of 1165 images correctly (87.039%). Epoch Loss: 0.308
# -  Testing dataset. Got 151 out of 196 images correctly (77.041%). Loss: 0.598
# Time taken for epoch 39: 37.55 seconds
# Epoch number: 40
#   -Training Dataset, Got 1003 out of 1165 images correctly (86.094%). Epoch Loss: 0.289
# -  Testing dataset. Got 161 out of 196 images correctly (82.143%). Loss: 0.647
# Time taken for epoch 40: 40.41 seconds
# Epoch number: 41
#   -Training Dataset, Got 1024 out of 1165 images correctly (87.897%). Epoch Loss: 0.274
# -  Testing dataset. Got 154 out of 196 images correctly (78.571%). Loss: 0.652
# Time taken for epoch 41: 48.62 seconds
# Epoch number: 42
#   -Training Dataset, Got 1036 out of 1165 images correctly (88.927%). Epoch Loss: 0.254
# -  Testing dataset. Got 152 out of 196 images correctly (77.551%). Loss: 0.556
# Time taken for epoch 42: 48.20 seconds
# Epoch number: 43
#   -Training Dataset, Got 1033 out of 1165 images correctly (88.670%). Epoch Loss: 0.252
# -  Testing dataset. Got 163 out of 196 images correctly (83.163%). Loss: 0.587
# Time taken for epoch 43: 45.63 seconds
# Epoch number: 44
#   -Training Dataset, Got 1024 out of 1165 images correctly (87.897%). Epoch Loss: 0.264
# -  Testing dataset. Got 142 out of 196 images correctly (72.449%). Loss: 0.791
# Time taken for epoch 44: 50.99 seconds
# Epoch number: 45
#   -Training Dataset, Got 1039 out of 1165 images correctly (89.185%). Epoch Loss: 0.247
# -  Testing dataset. Got 154 out of 196 images correctly (78.571%). Loss: 0.661
# Time taken for epoch 45: 51.76 seconds
# Epoch number: 46
#   -Training Dataset, Got 1034 out of 1165 images correctly (88.755%). Epoch Loss: 0.262
# -  Testing dataset. Got 151 out of 196 images correctly (77.041%). Loss: 0.697
# Time taken for epoch 46: 51.18 seconds
# Epoch number: 47
#   -Training Dataset, Got 1036 out of 1165 images correctly (88.927%). Epoch Loss: 0.243
# -  Testing dataset. Got 155 out of 196 images correctly (79.082%). Loss: 0.742
# Time taken for epoch 47: 50.92 seconds
# Epoch number: 48
#   -Training Dataset, Got 1037 out of 1165 images correctly (89.013%). Epoch Loss: 0.257
# -  Testing dataset. Got 159 out of 196 images correctly (81.122%). Loss: 0.689
# Time taken for epoch 48: 51.62 seconds
# Epoch number: 49
#   -Training Dataset, Got 1048 out of 1165 images correctly (89.957%). Epoch Loss: 0.237
# -  Testing dataset. Got 145 out of 196 images correctly (73.980%). Loss: 0.845
# Time taken for epoch 49: 52.31 seconds
# Epoch number: 50
#   -Training Dataset, Got 1031 out of 1165 images correctly (88.498%). Epoch Loss: 0.267
# -  Testing dataset. Got 159 out of 196 images correctly (81.122%). Loss: 0.583
# Time taken for epoch 50: 51.54 seconds
# Finished Training

# %%
np.save('max_epoch_timecvt400X.npy', max_epoch_time)

# Plot the maximum epoch time
plt.bar(['Model'], [max_epoch_time], color='skyblue')
plt.xlabel('Model')
plt.ylabel('Maximum Epoch Time (seconds)')
plt.title('Maximum Epoch Time Taken for the Model')
plt.show()

# %%
from ptflops import get_model_complexity_info

# Define a function to compute FLOPS
def get_flops(model, input_size):
    flops, params = get_model_complexity_info(model, input_size, as_strings=True, print_per_layer_stat=True)
    print(f"FLOPs: {flops}")
    print(f"Parameters: {params}")

# Define the input size. Here, it's a single image with 3 channels and size 512x512
input_size = (3,512,512)

# Compute FLOPS for the ViTForImageClassification model
get_flops(model, input_size)
# Out:
# CvtForImageClassification(
#   19.61 M, 99.998% Params, 21.24 GMac, 99.371% MACs,
#   (cvt): CvtModel(
#     19.61 M, 99.990% Params, 21.24 GMac, 99.371% MACs,
#     (encoder): CvtEncoder(
#       19.61 M, 99.990% Params, 21.24 GMac, 99.371% MACs,
#       (stages): ModuleList(
#         (0): CvtStage(
#           61.7 k, 0.315% Params, 892.34 MMac, 4.176% MACs,
#           (embedding): CvtEmbeddings(
#             9.6 k, 0.049% Params, 156.24 MMac, 0.731% MACs,
#             (convolution_embeddings): CvtConvEmbeddings(
#               9.6 k, 0.049% Params, 156.24 MMac, 0.731% MACs,
#               (projection): Conv2d(9.47 k, 0.048% Params, 155.19 MMac, 0.726% MACs, 3, 64, kernel_size=(7, 7), stride=(4, 4), padding=(2, 2))
#               (normalization): LayerNorm(128, 0.001% Params, 1.05 MMac, 0.005% MACs, (64,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             52.1 k, 0.266% Params, 736.1 MMac, 3.445% MACs,
#             (0): CvtLayer(
#               52.1 k, 0.266% Params, 736.1 MMac, 3.445% MACs,
#               (attention): CvtAttention(
#                 18.75 k, 0.096% Params, 187.7 MMac, 0.878% MACs,
#                 (attention): CvtSelfAttention(
#                   14.59 k, 0.074% Params, 119.54 MMac, 0.559% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     704, 0.004% Params, 11.53 MMac, 0.054% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       704, 0.004% Params, 11.53 MMac, 0.054% MACs,
#                       (convolution): Conv2d(576, 0.003% Params, 9.44 MMac, 0.044% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(128, 0.001% Params, 2.1 MMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     704, 0.004% Params, 2.88 MMac, 0.013% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       704, 0.004% Params, 2.88 MMac, 0.013% MACs,
#                       (convolution): Conv2d(576, 0.003% Params, 2.36 MMac, 0.011% MACs, 64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(128, 0.001% Params, 524.29 KMac, 0.002% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     704, 0.004% Params, 2.88 MMac, 0.013% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       704, 0.004% Params, 2.88 MMac, 0.013% MACs,
#                       (convolution): Conv2d(576, 0.003% Params, 2.36 MMac, 0.011% MACs, 64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(128, 0.001% Params, 524.29 KMac, 0.002% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(4.16 k, 0.021% Params, 68.16 MMac, 0.319% MACs, in_features=64, out_features=64, bias=True)
#                   (projection_key): Linear(4.16 k, 0.021% Params, 17.04 MMac, 0.080% MACs, in_features=64, out_features=64, bias=True)
#                   (projection_value): Linear(4.16 k, 0.021% Params, 17.04 MMac, 0.080% MACs, in_features=64, out_features=64, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   4.16 k, 0.021% Params, 68.16 MMac, 0.319% MACs,
#                   (dense): Linear(4.16 k, 0.021% Params, 68.16 MMac, 0.319% MACs, in_features=64, out_features=64, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 16.64 k, 0.085% Params, 276.82 MMac, 1.295% MACs,
#                 (dense): Linear(16.64 k, 0.085% Params, 272.63 MMac, 1.276% MACs, in_features=64, out_features=256, bias=True)
#                 (activation): GELU(0, 0.000% Params, 4.19 MMac, 0.020% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 16.45 k, 0.084% Params, 269.48 MMac, 1.261% MACs,
#                 (dense): Linear(16.45 k, 0.084% Params, 269.48 MMac, 1.261% MACs, in_features=256, out_features=64, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (layernorm_before): LayerNorm(128, 0.001% Params, 1.05 MMac, 0.005% MACs, (64,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(128, 0.001% Params, 1.05 MMac, 0.005% MACs, (64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (1): CvtStage(
#           1.01 M, 5.168% Params, 3.67 GMac, 17.186% MACs,
#           (embedding): CvtEmbeddings(
#             111.17 k, 0.567% Params, 454.56 MMac, 2.127% MACs,
#             (convolution_embeddings): CvtConvEmbeddings(
#               111.17 k, 0.567% Params, 454.56 MMac, 2.127% MACs,
#               (projection): Conv2d(110.78 k, 0.565% Params, 453.77 MMac, 2.123% MACs, 64, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (normalization): LayerNorm(384, 0.002% Params, 786.43 KMac, 0.004% MACs, (192,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             902.4 k, 4.601% Params, 3.22 GMac, 15.059% MACs,
#             (0): CvtLayer(
#               451.2 k, 2.300% Params, 1.61 GMac, 7.530% MACs,
#               (attention): CvtAttention(
#                 154.56 k, 0.788% Params, 392.43 MMac, 1.836% MACs,
#                 (attention): CvtSelfAttention(
#                   117.5 k, 0.599% Params, 240.65 MMac, 1.126% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     2.11 k, 0.011% Params, 8.65 MMac, 0.040% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       2.11 k, 0.011% Params, 8.65 MMac, 0.040% MACs,
#                       (convolution): Conv2d(1.73 k, 0.009% Params, 7.08 MMac, 0.033% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(384, 0.002% Params, 1.57 MMac, 0.007% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     2.11 k, 0.011% Params, 2.16 MMac, 0.010% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       2.11 k, 0.011% Params, 2.16 MMac, 0.010% MACs,
#                       (convolution): Conv2d(1.73 k, 0.009% Params, 1.77 MMac, 0.008% MACs, 192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(384, 0.002% Params, 393.22 KMac, 0.002% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     2.11 k, 0.011% Params, 2.16 MMac, 0.010% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       2.11 k, 0.011% Params, 2.16 MMac, 0.010% MACs,
#                       (convolution): Conv2d(1.73 k, 0.009% Params, 1.77 MMac, 0.008% MACs, 192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(384, 0.002% Params, 393.22 KMac, 0.002% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(37.06 k, 0.189% Params, 151.78 MMac, 0.710% MACs, in_features=192, out_features=192, bias=True)
#                   (projection_key): Linear(37.06 k, 0.189% Params, 37.95 MMac, 0.178% MACs, in_features=192, out_features=192, bias=True)
#                   (projection_value): Linear(37.06 k, 0.189% Params, 37.95 MMac, 0.178% MACs, in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   37.06 k, 0.189% Params, 151.78 MMac, 0.710% MACs,
#                   (dense): Linear(37.06 k, 0.189% Params, 151.78 MMac, 0.710% MACs, in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 148.22 k, 0.756% Params, 610.27 MMac, 2.856% MACs,
#                 (dense): Linear(148.22 k, 0.756% Params, 607.13 MMac, 2.841% MACs, in_features=192, out_features=768, bias=True)
#                 (activation): GELU(0, 0.000% Params, 3.15 MMac, 0.015% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 147.65 k, 0.753% Params, 604.77 MMac, 2.830% MACs,
#                 (dense): Linear(147.65 k, 0.753% Params, 604.77 MMac, 2.830% MACs, in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (layernorm_before): LayerNorm(384, 0.002% Params, 786.43 KMac, 0.004% MACs, (192,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(384, 0.002% Params, 786.43 KMac, 0.004% MACs, (192,), eps=1e-05, elementwise_affine=True)
#             )
#             (1): CvtLayer(
#               451.2 k, 2.300% Params, 1.61 GMac, 7.530% MACs,
#               (attention): CvtAttention(
#                 154.56 k, 0.788% Params, 392.43 MMac, 1.836% MACs,
#                 (attention): CvtSelfAttention(
#                   117.5 k, 0.599% Params, 240.65 MMac, 1.126% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     2.11 k, 0.011% Params, 8.65 MMac, 0.040% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       2.11 k, 0.011% Params, 8.65 MMac, 0.040% MACs,
#                       (convolution): Conv2d(1.73 k, 0.009% Params, 7.08 MMac, 0.033% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(384, 0.002% Params, 1.57 MMac, 0.007% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     2.11 k, 0.011% Params, 2.16 MMac, 0.010% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       2.11 k, 0.011% Params, 2.16 MMac, 0.010% MACs,
#                       (convolution): Conv2d(1.73 k, 0.009% Params, 1.77 MMac, 0.008% MACs, 192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(384, 0.002% Params, 393.22 KMac, 0.002% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     2.11 k, 0.011% Params, 2.16 MMac, 0.010% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       2.11 k, 0.011% Params, 2.16 MMac, 0.010% MACs,
#                       (convolution): Conv2d(1.73 k, 0.009% Params, 1.77 MMac, 0.008% MACs, 192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(384, 0.002% Params, 393.22 KMac, 0.002% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(37.06 k, 0.189% Params, 151.78 MMac, 0.710% MACs, in_features=192, out_features=192, bias=True)
#                   (projection_key): Linear(37.06 k, 0.189% Params, 37.95 MMac, 0.178% MACs, in_features=192, out_features=192, bias=True)
#                   (projection_value): Linear(37.06 k, 0.189% Params, 37.95 MMac, 0.178% MACs, in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   37.06 k, 0.189% Params, 151.78 MMac, 0.710% MACs,
#                   (dense): Linear(37.06 k, 0.189% Params, 151.78 MMac, 0.710% MACs, in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 148.22 k, 0.756% Params, 610.27 MMac, 2.856% MACs,
#                 (dense): Linear(148.22 k, 0.756% Params, 607.13 MMac, 2.841% MACs, in_features=192, out_features=768, bias=True)
#                 (activation): GELU(0, 0.000% Params, 3.15 MMac, 0.015% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 147.65 k, 0.753% Params, 604.77 MMac, 2.830% MACs,
#                 (dense): Linear(147.65 k, 0.753% Params, 604.77 MMac, 2.830% MACs, in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (layernorm_before): LayerNorm(384, 0.002% Params, 786.43 KMac, 0.004% MACs, (192,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(384, 0.002% Params, 786.43 KMac, 0.004% MACs, (192,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (2): CvtStage(
#           18.54 M, 94.508% Params, 16.67 GMac, 78.010% MACs,
#           (embedding): CvtEmbeddings(
#             664.7 k, 3.389% Params, 680.26 MMac, 3.183% MACs,
#             (convolution_embeddings): CvtConvEmbeddings(
#               664.7 k, 3.389% Params, 680.26 MMac, 3.183% MACs,
#               (projection): Conv2d(663.94 k, 3.385% Params, 679.87 MMac, 3.181% MACs, 192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (normalization): LayerNorm(768, 0.004% Params, 393.22 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             17.87 M, 91.119% Params, 15.99 GMac, 74.826% MACs,
#             (0): CvtLayer(
#               1.79 M, 9.112% Params, 1.6 GMac, 7.483% MACs,
#               (attention): CvtAttention(
#                 604.03 k, 3.080% Params, 385.55 MMac, 1.804% MACs,
#                 (attention): CvtSelfAttention(
#                   456.19 k, 2.326% Params, 234.01 MMac, 1.095% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 3.54 MMac, 0.017% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 786.43 KMac, 0.004% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs,
#                   (dense): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 591.36 k, 3.015% Params, 607.72 MMac, 2.844% MACs,
#                 (dense): Linear(591.36 k, 3.015% Params, 606.14 MMac, 2.836% MACs, in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(0, 0.000% Params, 1.57 MMac, 0.007% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs,
#                 (dense): Linear(590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs, in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.02222222276031971)
#               (layernorm_before): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#             (1): CvtLayer(
#               1.79 M, 9.112% Params, 1.6 GMac, 7.483% MACs,
#               (attention): CvtAttention(
#                 604.03 k, 3.080% Params, 385.55 MMac, 1.804% MACs,
#                 (attention): CvtSelfAttention(
#                   456.19 k, 2.326% Params, 234.01 MMac, 1.095% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 3.54 MMac, 0.017% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 786.43 KMac, 0.004% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs,
#                   (dense): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 591.36 k, 3.015% Params, 607.72 MMac, 2.844% MACs,
#                 (dense): Linear(591.36 k, 3.015% Params, 606.14 MMac, 2.836% MACs, in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(0, 0.000% Params, 1.57 MMac, 0.007% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs,
#                 (dense): Linear(590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs, in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.02222222276031971)
#               (layernorm_before): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#             (2): CvtLayer(
#               1.79 M, 9.112% Params, 1.6 GMac, 7.483% MACs,
#               (attention): CvtAttention(
#                 604.03 k, 3.080% Params, 385.55 MMac, 1.804% MACs,
#                 (attention): CvtSelfAttention(
#                   456.19 k, 2.326% Params, 234.01 MMac, 1.095% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 3.54 MMac, 0.017% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 786.43 KMac, 0.004% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs,
#                   (dense): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 591.36 k, 3.015% Params, 607.72 MMac, 2.844% MACs,
#                 (dense): Linear(591.36 k, 3.015% Params, 606.14 MMac, 2.836% MACs, in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(0, 0.000% Params, 1.57 MMac, 0.007% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs,
#                 (dense): Linear(590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs, in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.02222222276031971)
#               (layernorm_before): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#             (3): CvtLayer(
#               1.79 M, 9.112% Params, 1.6 GMac, 7.483% MACs,
#               (attention): CvtAttention(
#                 604.03 k, 3.080% Params, 385.55 MMac, 1.804% MACs,
#                 (attention): CvtSelfAttention(
#                   456.19 k, 2.326% Params, 234.01 MMac, 1.095% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 3.54 MMac, 0.017% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 786.43 KMac, 0.004% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs,
#                   (dense): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 591.36 k, 3.015% Params, 607.72 MMac, 2.844% MACs,
#                 (dense): Linear(591.36 k, 3.015% Params, 606.14 MMac, 2.836% MACs, in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(0, 0.000% Params, 1.57 MMac, 0.007% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs,
#                 (dense): Linear(590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs, in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.02222222276031971)
#               (layernorm_before): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#             (4): CvtLayer(
#               1.79 M, 9.112% Params, 1.6 GMac, 7.483% MACs,
#               (attention): CvtAttention(
#                 604.03 k, 3.080% Params, 385.55 MMac, 1.804% MACs,
#                 (attention): CvtSelfAttention(
#                   456.19 k, 2.326% Params, 234.01 MMac, 1.095% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 3.54 MMac, 0.017% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 786.43 KMac, 0.004% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs,
#                   (dense): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 591.36 k, 3.015% Params, 607.72 MMac, 2.844% MACs,
#                 (dense): Linear(591.36 k, 3.015% Params, 606.14 MMac, 2.836% MACs, in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(0, 0.000% Params, 1.57 MMac, 0.007% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs,
#                 (dense): Linear(590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs, in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.02222222276031971)
#               (layernorm_before): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#             (5): CvtLayer(
#               1.79 M, 9.112% Params, 1.6 GMac, 7.483% MACs,
#               (attention): CvtAttention(
#                 604.03 k, 3.080% Params, 385.55 MMac, 1.804% MACs,
#                 (attention): CvtSelfAttention(
#                   456.19 k, 2.326% Params, 234.01 MMac, 1.095% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 3.54 MMac, 0.017% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 786.43 KMac, 0.004% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs,
#                   (dense): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 591.36 k, 3.015% Params, 607.72 MMac, 2.844% MACs,
#                 (dense): Linear(591.36 k, 3.015% Params, 606.14 MMac, 2.836% MACs, in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(0, 0.000% Params, 1.57 MMac, 0.007% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs,
#                 (dense): Linear(590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs, in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.02222222276031971)
#               (layernorm_before): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#             (6): CvtLayer(
#               1.79 M, 9.112% Params, 1.6 GMac, 7.483% MACs,
#               (attention): CvtAttention(
#                 604.03 k, 3.080% Params, 385.55 MMac, 1.804% MACs,
#                 (attention): CvtSelfAttention(
#                   456.19 k, 2.326% Params, 234.01 MMac, 1.095% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 3.54 MMac, 0.017% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 786.43 KMac, 0.004% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs,
#                   (dense): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 591.36 k, 3.015% Params, 607.72 MMac, 2.844% MACs,
#                 (dense): Linear(591.36 k, 3.015% Params, 606.14 MMac, 2.836% MACs, in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(0, 0.000% Params, 1.57 MMac, 0.007% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs,
#                 (dense): Linear(590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs, in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.02222222276031971)
#               (layernorm_before): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#             (7): CvtLayer(
#               1.79 M, 9.112% Params, 1.6 GMac, 7.483% MACs,
#               (attention): CvtAttention(
#                 604.03 k, 3.080% Params, 385.55 MMac, 1.804% MACs,
#                 (attention): CvtSelfAttention(
#                   456.19 k, 2.326% Params, 234.01 MMac, 1.095% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 3.54 MMac, 0.017% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 786.43 KMac, 0.004% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs,
#                   (dense): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 591.36 k, 3.015% Params, 607.72 MMac, 2.844% MACs,
#                 (dense): Linear(591.36 k, 3.015% Params, 606.14 MMac, 2.836% MACs, in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(0, 0.000% Params, 1.57 MMac, 0.007% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs,
#                 (dense): Linear(590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs, in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.02222222276031971)
#               (layernorm_before): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#             (8): CvtLayer(
#               1.79 M, 9.112% Params, 1.6 GMac, 7.483% MACs,
#               (attention): CvtAttention(
#                 604.03 k, 3.080% Params, 385.55 MMac, 1.804% MACs,
#                 (attention): CvtSelfAttention(
#                   456.19 k, 2.326% Params, 234.01 MMac, 1.095% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 3.54 MMac, 0.017% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 786.43 KMac, 0.004% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs,
#                   (dense): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 591.36 k, 3.015% Params, 607.72 MMac, 2.844% MACs,
#                 (dense): Linear(591.36 k, 3.015% Params, 606.14 MMac, 2.836% MACs, in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(0, 0.000% Params, 1.57 MMac, 0.007% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs,
#                 (dense): Linear(590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs, in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.02222222276031971)
#               (layernorm_before): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#             (9): CvtLayer(
#               1.79 M, 9.112% Params, 1.6 GMac, 7.483% MACs,
#               (attention): CvtAttention(
#                 604.03 k, 3.080% Params, 385.55 MMac, 1.804% MACs,
#                 (attention): CvtSelfAttention(
#                   456.19 k, 2.326% Params, 234.01 MMac, 1.095% MACs,
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 4.33 MMac, 0.020% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 3.54 MMac, 0.017% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 786.43 KMac, 0.004% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       4.22 k, 0.022% Params, 1.08 MMac, 0.005% MACs,
#                       (convolution): Conv2d(3.46 k, 0.018% Params, 884.74 KMac, 0.004% MACs, 384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(768, 0.004% Params, 196.61 KMac, 0.001% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (projection_query): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(147.84 k, 0.754% Params, 37.99 MMac, 0.178% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs,
#                   (dense): Linear(147.84 k, 0.754% Params, 151.54 MMac, 0.709% MACs, in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 591.36 k, 3.015% Params, 607.72 MMac, 2.844% MACs,
#                 (dense): Linear(591.36 k, 3.015% Params, 606.14 MMac, 2.836% MACs, in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(0, 0.000% Params, 1.57 MMac, 0.007% MACs, approximate='none')
#               )
#               (output): CvtOutput(
#                 590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs,
#                 (dense): Linear(590.21 k, 3.009% Params, 604.96 MMac, 2.831% MACs, in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.02222222276031971)
#               (layernorm_before): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm(768, 0.004% Params, 393.6 KMac, 0.002% MACs, (384,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm(768, 0.004% Params, 384.0 Mac, 0.000% MACs, (384,), eps=1e-05, elementwise_affine=True)
#   (classifier): Linear(770, 0.004% Params, 770.0 Mac, 0.000% MACs, in_features=384, out_features=2, bias=True)
# )
# FLOPs: 21.37 GMac
# Parameters: 19.61 M

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
total_params = count_parameters(model)
print(f"Total number of parameters in the integrated model: {total_params}")
# Out:
# Total number of parameters in the integrated model: 19613250

# %%
model_path = 'Models/cvt_400X.pth'
check = torch.load(model_path)
# Out:
# C:\Users\Utkarsh Varman\AppData\Local\Temp\ipykernel_20756\1797744825.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   check = torch.load(model_path)

# %%
check['best accuracy']
# Out:
# 84.6938775510204

# %%
folder_path = 'Graphs/cvt_400X/'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

plt.figure(figsize=(10, 5))

# Plotting Accuracy
plt.subplot(1, 2, 1)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.ylim(0, 100)  # Set y-axis limits from 0 to 100 for uniformity
plt.legend()
plt.savefig(os.path.join(folder_path, 'accuracy_curve_cvt400X.png'))

# Plotting Loss
plt.subplot(1, 2, 2)
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.savefig(os.path.join(folder_path, 'loss_curve_cvt400X.png'))

# Save the figure
plt.tight_layout()
plt.savefig(os.path.join(folder_path, 'training_curves_cvt400X.png'))

plt.show()

# %%
model.load_state_dict(check['model'])
# Out:
# <All keys matched successfully>

# %%
def evaluate_model(model,test_loader,criterion):
    model.eval()
    predicted_correctly = 0
    total = 0
    device = set_device()
    running_loss = 0.0

    with torch.no_grad():
          for data in tqdm(test_loader,desc='Evaluating'):
            images,labels = data
            images = images.to(device)
            labels = labels.to(device)
            total += labels.size(0)

            outputs = model(images)

            _,predicted = torch.max(outputs.logits,1)
            loss = criterion(outputs.logits,labels)
            running_loss+=loss.item()

            predicted_correctly+=(predicted==labels).sum().item()
    epoch_acc = 100.0*predicted_correctly/total
    epoch_loss = running_loss/len(test_loader)
    print('-  Testing dataset. Got %d out of %d images correctly (%0.3f%%). Loss: %0.3f' % (predicted_correctly, total, epoch_acc,epoch_loss))

    return epoch_acc,epoch_loss

# %%
evaluate_model(model,test_loader,criterion)
# Out:
# Evaluating:   0%|          | 0/58 [00:00<?, ?it/s]
# Evaluating: 100%|██████████| 58/58 [00:13<00:00,  4.18it/s]
# -  Testing dataset. Got 391 out of 459 images correctly (85.185%). Loss: 0.472
# (85.18518518518519, 0.4724505013818371)

# %%
def evaluate_model_classification_report(model, test_loader):
    model.eval()
    true_labels = []
    predicted_labels = []
    device = set_device()

    with torch.no_grad():
        for data in test_loader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            true_labels.extend(labels.cpu().numpy())

            outputs = model(images)
            _, predicted = torch.max(outputs.logits, 1)
            predicted_labels.extend(predicted.cpu().numpy())

    return true_labels, predicted_labels

# %%
true_labels, predicted_labels = evaluate_model_classification_report(model, test_loader)

# %%
from sklearn.metrics import classification_report,roc_auc_score
print(classification_report(true_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.72      0.79       179
#            1       0.84      0.94      0.89       280
#
#     accuracy                           0.85       459
#    macro avg       0.86      0.83      0.84       459
# weighted avg       0.85      0.85      0.85       459

# %%
auc_score = roc_auc_score(true_labels, predicted_labels)
print("AUC Score:", auc_score)
# Out:
# AUC Score: 0.8281923383878691

# %% [markdown]
# <b>Explainability</b>

# %%
img_path = 'fold1_seperated_2_classes/test/400X/Malignant/SOB_M_DC-14-16716-400-010.png'
img = Image.open(img_path)

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=700x460>

# %%
img = img.resize((512,512))

# %%
model.to(device)
# Out:
# CvtForImageClassification(
#   (cvt): CvtModel(
#     (encoder): CvtEncoder(
#       (stages): ModuleList(
#         (0): CvtStage(
#           (embedding): CvtEmbeddings(
#             (convolution_embeddings): CvtConvEmbeddings(
#               (projection): Conv2d(3, 64, kernel_size=(7, 7), stride=(4, 4), padding=(2, 2))
#               (normalization): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             (0): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=64, out_features=64, bias=True)
#                   (projection_key): Linear(in_features=64, out_features=64, bias=True)
#                   (projection_value): Linear(in_features=64, out_features=64, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=64, out_features=64, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=64, out_features=256, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=256, out_features=64, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): Identity()
#               (layernorm_before): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (1): CvtStage(
#           (embedding): CvtEmbeddings(
#             (convolution_embeddings): CvtConvEmbeddings(
#               (projection): Conv2d(64, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (normalization): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             (0): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_key): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_value): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=192, out_features=768, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): Identity()
#               (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#             (1): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_key): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_value): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=192, out_features=768, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): Identity()
#               (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (2): CvtStage(
#           (embedding): CvtEmbeddings(
#             (convolution_embeddings): CvtConvEmbeddings(
#               (projection): Conv2d(192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (normalization): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             (0): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (1): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (2): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (3): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (4): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (5): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (6): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (7): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (8): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (9): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   (classifier): Linear(in_features=384, out_features=2, bias=True)
# )

# %%
def image_transform():
  transform = transforms.Compose([
    transforms.Resize((512,512)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.7590, 0.5809, 0.7404],std = [0.1195, 0.1602, 0.0887])
    ])
  return transform
transform_new = image_transform()

# %%
img_tensor = transform_new(img)
X = transform(img).unsqueeze(0)
img_tensor.shape
# Out:
# torch.Size([3, 512, 512])

# %%
logits = model(X.to(device))

# %%
_,index = torch.max(logits.logits,dim=1)
classes = ['Benign','Malignant']
print(classes[index])
# Out:
# Malignant

# %%
model.eval()
# Out:
# CvtForImageClassification(
#   (cvt): CvtModel(
#     (encoder): CvtEncoder(
#       (stages): ModuleList(
#         (0): CvtStage(
#           (embedding): CvtEmbeddings(
#             (convolution_embeddings): CvtConvEmbeddings(
#               (projection): Conv2d(3, 64, kernel_size=(7, 7), stride=(4, 4), padding=(2, 2))
#               (normalization): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             (0): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                       (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=64, out_features=64, bias=True)
#                   (projection_key): Linear(in_features=64, out_features=64, bias=True)
#                   (projection_value): Linear(in_features=64, out_features=64, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=64, out_features=64, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=64, out_features=256, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=256, out_features=64, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): Identity()
#               (layernorm_before): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (1): CvtStage(
#           (embedding): CvtEmbeddings(
#             (convolution_embeddings): CvtConvEmbeddings(
#               (projection): Conv2d(64, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (normalization): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             (0): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_key): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_value): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=192, out_features=768, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): Identity()
#               (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#             (1): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#                       (normalization): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_key): Linear(in_features=192, out_features=192, bias=True)
#                   (projection_value): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=192, out_features=192, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=192, out_features=768, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=768, out_features=192, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): Identity()
#               (layernorm_before): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (2): CvtStage(
#           (embedding): CvtEmbeddings(
#             (convolution_embeddings): CvtConvEmbeddings(
#               (projection): Conv2d(192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (normalization): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layers): Sequential(
#             (0): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (1): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (2): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (3): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (4): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (5): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (6): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (7): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (8): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#             (9): CvtLayer(
#               (attention): CvtAttention(
#                 (attention): CvtSelfAttention(
#                   (convolution_projection_query): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_key): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (convolution_projection_value): CvtSelfAttentionProjection(
#                     (convolution_projection): CvtSelfAttentionConvProjection(
#                       (convolution): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#                       (normalization): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     )
#                     (linear_projection): CvtSelfAttentionLinearProjection()
#                   )
#                   (projection_query): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_key): Linear(in_features=384, out_features=384, bias=True)
#                   (projection_value): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#                 (output): CvtSelfOutput(
#                   (dense): Linear(in_features=384, out_features=384, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (intermediate): CvtIntermediate(
#                 (dense): Linear(in_features=384, out_features=1536, bias=True)
#                 (activation): GELU(approximate='none')
#               )
#               (output): CvtOutput(
#                 (dense): Linear(in_features=1536, out_features=384, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (drop_path): CvtDropPath(p=0.02222222276031971)
#               (layernorm_before): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#               (layernorm_after): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (layernorm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   (classifier): Linear(in_features=384, out_features=2, bias=True)
# )

# %%
from transformers import CvtForImageClassification
from functools import partial
from typing import List, Callable, Optional
from pytorch_grad_cam import run_dff_on_image, GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image


class ClassifierOutputTarget:
    def __init__(self, category):
        self.category = category

    def __call__(self, model_output):
        if len(model_output.shape) == 1:
            return model_output[self.category]
        return model_output[:, self.category]   
    
CATEGORY_NAMES = ["Benign", "Malignant"]

def category_name_to_index(model, category_name):
    return CATEGORY_NAMES.index(category_name)

def print_top_categories(model, img_tensor):
    logits = model(img_tensor.unsqueeze(0)).logits
    
    probabilities = torch.nn.functional.softmax(logits, dim=1)[0]
    
    max_index = torch.argmax(probabilities).item()
    predicted_category = CATEGORY_NAMES[max_index]
    predicted_probability = probabilities[max_index].item() * 100  # Convert to percentage
 
    #print(f"Predicted Class: {predicted_category}")
    #print(f"Class Probabilities:")
    for idx, category in enumerate(CATEGORY_NAMES):
        print(f"  {category}: {probabilities[idx].item() * 100:.2f}%")
    
    return max_index, predicted_probability


def reshape_transform_cvt_huggingface(tensor, model, width, height):
    tensor = tensor[:, 1:, :]
    tensor = tensor.reshape(tensor.size(0), height, width, tensor.size(-1))
    norm = model.layernorm(tensor)
    return norm.transpose(2, 3).transpose(1, 2)

def reshape_gradcam_transform_cvt_huggingface(tensor, model, width, height):
    tensor = tensor[:, 1:, :]
    tensor = tensor.reshape(tensor.size(0), height, width, tensor.size(-1))
    return tensor.transpose(2, 3).transpose(1, 2)

#model = CvtForImageClassification.from_pretrained("microsoft/cvt-13")
model = CvtForImageClassification(configuration)
model_path = 'Models/cvt_400X.pth'
check = torch.load(model_path)
model.load_state_dict(check['model'])
model.eval()
reshape_transform = partial(reshape_transform_cvt_huggingface, model=model,
                            width=img_tensor.shape[2] // 16, height=img_tensor.shape[1] // 16)
reshape_transform_gradcam = partial(reshape_gradcam_transform_cvt_huggingface, model=model,
                                     width=img_tensor.shape[2] // 16, height=img_tensor.shape[1] // 16)

targets_for_gradcam = [ClassifierOutputTarget(category_name_to_index(model, "Malignant")),
                       ClassifierOutputTarget(category_name_to_index(model, "Benign"))]

target_layer_dff = model.cvt.encoder.stages[-1].layers[-1]
target_layer_gradcam = model.cvt.encoder.stages[-1].layers[-2]

class HuggingfaceToTensorModelWrapper(torch.nn.Module):
    def __init__(self, model):
        super(HuggingfaceToTensorModelWrapper, self).__init__()
        self.model = model

    def forward(self, x):
        return self.model(x).logits

def run_grad_cam_on_image(model: torch.nn.Module,
                          target_layer: torch.nn.Module,
                          targets_for_gradcam: List[Callable],
                          reshape_transform: Optional[Callable],
                          input_tensor: torch.Tensor=img_tensor,
                          input_image: Image=img,
                          method: Callable=GradCAM):
    with method(model=HuggingfaceToTensorModelWrapper(model),
                 target_layers=[target_layer],
                 reshape_transform=reshape_transform) as cam:
        
        repeated_tensor = input_tensor[None, :].repeat(len(targets_for_gradcam), 1, 1, 1)
        batch_results = cam(input_tensor=repeated_tensor, targets=targets_for_gradcam)
        
        results = []
        for i, grayscale_cam in enumerate(batch_results):
            category_name = "Benign" if i == 0 else "Malignant"
            visualization = show_cam_on_image(np.float32(input_image) / 255, grayscale_cam, use_rgb=True)
            visualization = cv2.resize(visualization, (visualization.shape[1] // 2, visualization.shape[0] // 2))
            
            results.append(visualization)
        return np.hstack(results)


top_category_index, top_probability = print_top_categories(model, img_tensor)

target_for_gradcam = ClassifierOutputTarget(top_category_index)

grad_cam_result = run_grad_cam_on_image(
    model=model,
    target_layer=target_layer_gradcam,
    targets_for_gradcam=[target_for_gradcam],
    reshape_transform=reshape_transform_gradcam
)
def plot_images(input_image: np.ndarray, gradcam_image: np.ndarray):
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    
    # Plot the original input image
    ax[0].imshow(input_image.astype(np.uint8))  # Ensure input_image is in uint8 format
    ax[0].set_title("Input Image")
    ax[0].axis("off")
    
    # Plot the Grad-CAM visualization
    ax[1].imshow(gradcam_image)
    ax[1].set_title("Grad-CAM Visualization")
    ax[1].axis("off")
    
    plt.tight_layout()
    plt.show()


input_image_np = np.array(img) 
plot_images(input_image_np, grad_cam_result)

print_top_categories(model, img_tensor)
# Out:
# C:\Users\Utkarsh Varman\AppData\Local\Temp\ipykernel_20756\206523926.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   check = torch.load(model_path)
#   Benign: 3.05%
#   Malignant: 96.95%
#   Benign: 3.05%
#   Malignant: 96.95%
# (1, 96.9497799873352)
